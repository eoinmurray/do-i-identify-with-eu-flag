# %% [markdown]
# # Do I identify with the EU Flag?

# %%
import pandas as pd
import country_converter as coco

# %%
cols2skip = [0]
cols = [i for i in range(100) if i not in cols2skip]

df_raw = pd.read_excel('./data/eb_90_volume_A.xls', sheet_name="QD11.3", skiprows=8, usecols=cols)
df_raw.rename(columns={'UE28\nEU28':'EU28', 'UE28-UK\nEU28-UK':'EU28-UK' }, inplace=True)
df = df_raw.transpose()
df = df.rename(columns=df.iloc[0])
df = df.iloc[1:]

iso3 = coco.convert(names=df.index.tolist(), to='ISO3', not_found=None)
# Out:
# WARNING:root:EU28 not found in regex
# WARNING:root:EU28-UK not found in regex
# WARNING:root:D-W not found in ISO3
# WARNING:root:D-E not found in ISO3
# WARNING:root:EL not found in ISO2
# WARNING:root:CY (tcc) not found in regex
# WARNING:root:UK not found in ISO2

# %%
# %run plot.ipynb
make_plot(locations=iso3, z=df['Tend to agree'] * 100)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
